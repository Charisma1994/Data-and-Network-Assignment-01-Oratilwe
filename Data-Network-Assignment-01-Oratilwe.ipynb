# %% [markdown]
# # Introduction
#
# The data below is an educational data set which is collected from learning management system (LMS) called Kalboard 360, describe the performance of students from various Grades and Countries in a semester and various factors which play a role in their performance.
#
# The data is collected using a learner activity tracker tool, which called experience API (xAPI).
# The xAPI is a component of the training and learning architecture (TLA) that enables to monitor learning progress and learner’s actions like reading an article or watching a training video.
# The API helps the learning activity providers to determine the learner, activity and those objects that describe a learning experience. The dataset below consists of 480 student records and 16 features. The features are classified into three categories: (1) Demographic features such as gender and nationality. (2) Academic background features such as educational stage, grade Level and section. (3) Behavioral features such as raised hand on class, opening resources, answering survey by parents, and school satisfaction.
#
# I'm trying to determine what among the factors listed above actually affects the students performance is it the relationship they have with their parents or not?, and  also determine some measures which one can take in order to diagnose the problem and find alternative measures to boasting the student's education performance.

# %% [markdown]
# # Type of method:
# For this problem I used the Logistic Regression since my data was categorical to determine the association between the student's relationship their parents either mother or father and their performance.

# %%
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns

# %%
os.chdir("/home/oratilwe/Desktop/MAXIMA/DataScience/Data-Networks-Assignment-01-Oratilwe")

# %%
df = pd.read_csv("xAPI-Edu-Data.csv")

# %%
formula = 'df.Relation ~ df.raisedhands + df.VisITedResources + df.AnnouncementsView + df.Discussion + df.StudentAbsenceDays'

# %%
mod = smf.glm(formula = formula, data = df, family = sm.families.Binomial())

# %%
results = mod.fit()

# %%
print(results.summary())
# Out:
#                               Generalized Linear Model Regression Results
# ...
# Dep. Variable:     ['df.Relation[Father]', 'df.Relation[Mum]']   No. Observations:                  480
# Model:                                                     GLM   Df Residuals:                      474
# Model Family:                                         Binomial   Df Model:                            5
# Link Function:                                           logit   Scale:                             1.0
# Method:                                                   IRLS   Log-Likelihood:                -276.52
# Date:                                         Tue, 16 May 2017   Deviance:                       553.04
# Time:                                                 19:38:58   Pearson chi2:                     470.
# No. Iterations:                                              6
# ...
#                                        coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ...

# %% [markdown]
# # Analysis
#
# Based on the GLM regression results we can see that there is an association between the relation(Mum and Father) and student abscence days, thus one can say that the one factor which contribute to the student's poor performance is the number of days they are absent from.

# %% [markdown]
# # Data Visualization and exploration for: Father

# %%
Father = df.loc[df.Relation ==  'Father']

# %%
sns.countplot(x='ParentschoolSatisfaction',data = Father, hue='Class',palette='bright')
plt.show()

# %% [markdown]
# # Box Plots

# %%
Raised_hand = sns.boxplot(x="Class", y="VisITedResources", data=Father)
plt.show()

# %%
Raised_hand = sns.boxplot(x="Class", y="AnnouncementsView", data=Father)
plt.show()

# %%
Raised_hand = sns.boxplot(x="Class", y="Discussion", data=Father)
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Students who relate with their father performed bad most of them in various levels like in the lower levels and middle levels, this is because students who relate with their father most of them didn't take part in some class activities and also they spent more days absent from school more than those who relate with their Mothers.

# %% [markdown]
# # Data Visualization and exploration for: Mother

# %%
Mother = df.loc[df.Relation ==  'Mum']

# %%
sns.countplot(x='ParentschoolSatisfaction',data = Mother, hue='Class',palette='bright')
plt.show()

# %% [markdown]
# # Box Plots

# %%
Raised_hand = sns.boxplot(x = "Class", y = "VisITedResources", data = Mother)
plt.show()

# %%
Raised_hand = sns.boxplot(x = "Class", y = "AnnouncementsView", data = Mother)
plt.show()

# %%
Raised_hand = sns.boxplot(x = "Class", y = "Discussion", data = Mother)
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
#  From the above plots we see that the students whose mothers were responsible for them participated in class and most of them didn't skip classes, this made them to perform very well in their education as compared to those relating with their fathers.

# %% [markdown]
# # Remarks:

# %% [markdown]
#  In conclusion we see that students who did well, a large majority of their parents were satisfied with the education they received, and those students whose parents were least satisfied with the school performed much worse. Also we saw that Mothers are good role models as compared to Fathers in terms of modelling, shaping and also boosting the performance of students in terms of their education. One solution I can think of to the problem is that both fathers and mothers should share with each other how they can ensure the success of their childern in terms education and make sure that atleast all of them become successful and perform good every semester and also determine ways to improve the relationship they have with their kids by increase their interactions and creating more time for them.
